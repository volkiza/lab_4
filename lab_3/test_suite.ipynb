# %%
import unittest
from testDistance import TestDistance
from testStats import TestStats
from bootstrap_test import TestBoot
from boot_func_test import Boot_func_test
from z_score_test import TestZ_score
from knn_test import TestKnn
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# test_dotProd (testDistance.TestDistance) ... ok
# test_eDist (testDistance.TestDistance) ...
# 29
# 3.605551275463989
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK
# test_dotProd (testDistance.TestDistance) ... ok
# test_eDist (testDistance.TestDistance) ... ok
# test_mean (testStats.TestStats) ... ok
# test_median (testStats.TestStats) ... ok
# test_sampleSd (testStats.TestStats) ... ok
# test_sampleVar (testStats.TestStats) ... ok
# test_std (testStats.TestStats) ... ok
# test_var (testStats.TestStats) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.006s
#
# OK
# test_is_instance (bootstrap_test.TestBoot) ... ok
# test_mean (bootstrap_test.TestBoot) ... ok
# test_sd (bootstrap_test.TestBoot) ... ok
# test_se (bootstrap_test.TestBoot) ... ok
# test_dotProd (testDistance.TestDistance) ... ok
# test_eDist (testDistance.TestDistance) ... ok
# test_mean (testStats.TestStats) ... ok
# test_median (testStats.TestStats) ... ok
# test_sampleSd (testStats.TestStats) ... ok
# test_sampleVar (testStats.TestStats) ... ok
# test_std (testStats.TestStats) ... ok
# test_var (testStats.TestStats) ... ok
#
# ----------------------------------------------------------------------
# Ran 12 tests in 0.012s
#
# OK
# test_resample (boot_func_test.Boot_func_test) ... ok
# test_sample_distr (boot_func_test.Boot_func_test) ...
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# setupclass TestBoot
# The variables are initialized
# Check if the part of instance class
# The test is over
# The variables are initialized
# Test mean
# The test is over
# The variables are initialized
# Test sd
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass TestBoot
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# setupclass Boot_func_test
# The variables are initialized
# Test resample
# The test is over
# The variables are initialized
# Test sample_distr
# ok
# test_sample_stand_err (boot_func_test.Boot_func_test) ... ok
# test_stand_err (boot_func_test.Boot_func_test) ... ok
# test_is_instance (bootstrap_test.TestBoot) ... ok
# test_mean (bootstrap_test.TestBoot) ... ok
# test_sd (bootstrap_test.TestBoot) ... ok
# test_se (bootstrap_test.TestBoot) ... ok
# test_dotProd (testDistance.TestDistance) ... ok
# test_eDist (testDistance.TestDistance) ... ok
# test_mean (testStats.TestStats) ... ok
# test_median (testStats.TestStats) ... ok
# test_sampleSd (testStats.TestStats) ... ok
# test_sampleVar (testStats.TestStats) ... ok
# test_std (testStats.TestStats) ... ok
# test_var (testStats.TestStats) ... ok
#
# ----------------------------------------------------------------------
# Ran 16 tests in 0.682s
#
# OK
# test_resample (boot_func_test.Boot_func_test) ... ok
# test_sample_distr (boot_func_test.Boot_func_test) ...
# The test is over
# The variables are initialized
# Test sample_stand_err
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass Boot_func_test
# setupclass TestBoot
# The variables are initialized
# Check if the part of instance class
# The test is over
# The variables are initialized
# Test mean
# The test is over
# The variables are initialized
# Test sd
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass TestBoot
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# setupclass Boot_func_test
# The variables are initialized
# Test resample
# The test is over
# The variables are initialized
# Test sample_distr
# ok
# test_sample_stand_err (boot_func_test.Boot_func_test) ... ok
# test_stand_err (boot_func_test.Boot_func_test) ... ok
# test_is_instance (bootstrap_test.TestBoot) ... ok
# test_mean (bootstrap_test.TestBoot) ... ok
# test_sd (bootstrap_test.TestBoot) ... ok
# test_se (bootstrap_test.TestBoot) ... ok
# test_dotProd (testDistance.TestDistance) ... ok
# test_eDist (testDistance.TestDistance) ... ok
# test_mean (testStats.TestStats) ... ok
# test_median (testStats.TestStats) ... ok
# test_sampleSd (testStats.TestStats) ... ok
# test_sampleVar (testStats.TestStats) ... ok
# test_std (testStats.TestStats) ... ok
# test_var (testStats.TestStats) ... ok
# test_p_se (z_score_test.TestZ_score) ... ok
# test_p_zscore (z_score_test.TestZ_score) ...
# The test is over
# The variables are initialized
# Test sample_stand_err
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass Boot_func_test
# setupclass TestBoot
# The variables are initialized
# Check if the part of instance class
# The test is over
# The variables are initialized
# Test mean
# The test is over
# The variables are initialized
# Test sd
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass TestBoot
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# ok
#
# ----------------------------------------------------------------------
# Ran 18 tests in 0.679s
#
# OK

# %%
def my_suite():
    suite=unittest.TestSuite()
    result=unittest.TestResult()
    suite.addTest(unittest.makeSuite(TestDistance))
    suite.addTest(unittest.makeSuite(TestStats))
    suite.addTest(unittest.makeSuite(Boot_func_test))
    suite.addTest(unittest.makeSuite(TestBoot))
    suite.addTest(unittest.makeSuite(TestZ_score))
    suite.addTest(unittest.makeSuite(TestKnn))
    runner=unittest.TextTestRunner()
    print(runner.run(suite))
my_suite()
# Out:
# .........
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# setupclass Boot_func_test
# The variables are initialized
# Test resample
# The test is over
# The variables are initialized
# Test sample_distr
# ..........
# The test is over
# The variables are initialized
# Test sample_stand_err
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass Boot_func_test
# setupclass TestBoot
# The variables are initialized
# Check if the part of instance class
# The test is over
# The variables are initialized
# Test mean
# The test is over
# The variables are initialized
# Test sd
# The test is over
# The variables are initialized
# Test stand_err
# The test is over
# teardownClass TestBoot
# Set Up Class
# Set Up
# Tear Down
# Set Up
# Tear Down
# Tear Down Class
# Set Up Class
# Set Up
# Tear Down
# Tear Down Class
# <unittest.runner.TextTestResult run=19 errors=0 failures=0>
# ----------------------------------------------------------------------
# Ran 19 tests in 0.711s
#
# OK
